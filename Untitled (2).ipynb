# %% [markdown]
# # Reading & Writing

# %%
import pandas as pd
#for reading file data
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book1.csv")
#df = pd.read_excel("Book1.xlsx","Sheet1")
df
# Out:
#           day  temperature  winds  event
# 0  01-01-2017           32     10   Rain
# 1  01-02-2017           35      8  Sunny
# 2  01-03-2017           38      6   Rain
# 3  01-04-2017           41      4   Rain
# 4  01-05-2017           44      2  Sunny
# 5  01-06-2017           47      0   Rain

# %%
import pandas as pd
#header = none , names =['ticker','eps','revenue','price','people']...for mising header
#nrows = 3...for limiting lines read
na_values=['not available','n.a.']#...for cleaning & munging & wrangling...use dictionary for specifying instead of list
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book2.csv",header=1,na_values={'eps':['not available','n.a.'],
                                                                               'revenue':['not available','n.a.',-1],
                                                                                 'people':['not available','n.a.']})
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2   MSFET  -1.00     85.0    64     bill gates
# 3     RIL    NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
#To Write
columns =['tickers','eps']...for slective column
#header = False...for no header
df.to_csv('new.csv',index=False)

# %% [markdown]
# # Handling Missing Data

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book3.csv",parse_dates=['day'])
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        9.0   Sunny
# 2017-01-03         28.0        NaN    Snow
# 2017-01-04          NaN        7.0     NaN
# 2017-01-05         32.0        NaN    Rain
# 2017-01-06          NaN        NaN   Sunny
# 2017-01-07          NaN        NaN     NaN
# 2017-01-08         34.0        8.0  Cloudy
# 2017-01-09         40.0       12.0   Sunny

# %%
new_df=df.fillna({'event':'no-event',
                 'windspeed':0,
                 'temperature':0})
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-02          0.0        9.0     Sunny
# 2017-01-03         28.0        0.0      Snow
# 2017-01-04          0.0        7.0  no-event
# 2017-01-05         32.0        0.0      Rain
# 2017-01-06          0.0        0.0     Sunny
# 2017-01-07          0.0        0.0  no-event
# 2017-01-08         34.0        8.0    Cloudy
# 2017-01-09         40.0       12.0     Sunny

# %%
#bfill...to fill prev value
#axis = ...method of copying

new_df = df.fillna(method="ffill",limit=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02         32.0        9.0   Sunny
# 2017-01-03         28.0        9.0    Snow
# 2017-01-04         28.0        7.0    Snow
# 2017-01-05         32.0        7.0    Rain
# 2017-01-06         32.0        NaN   Sunny
# 2017-01-07          NaN        NaN   Sunny
# 2017-01-08         34.0        8.0  Cloudy
# 2017-01-09         40.0       12.0   Sunny

# %%
new_df = df.interpolate(method="time")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-02    30.000000       9.00   Sunny
# 2017-01-03    28.000000       8.00    Snow
# 2017-01-04    30.000000       7.00     NaN
# 2017-01-05    32.000000       7.25    Rain
# 2017-01-06    32.666667       7.50   Sunny
# 2017-01-07    33.333333       7.75     NaN
# 2017-01-08    34.000000       8.00  Cloudy
# 2017-01-09    40.000000      12.00   Sunny

# %%
#thresh=1...with at leasy one valid value
new_df = df.dropna(how="all")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        9.0   Sunny
# 2017-01-03         28.0        NaN    Snow
# 2017-01-04          NaN        7.0     NaN
# 2017-01-05         32.0        NaN    Rain
# 2017-01-06          NaN        NaN   Sunny
# 2017-01-08         34.0        8.0  Cloudy
# 2017-01-09         40.0       12.0   Sunny

# %%
#for inserting missing range
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        9.0   Sunny
# 2017-01-03         28.0        NaN    Snow
# 2017-01-04          NaN        7.0     NaN
# 2017-01-05         32.0        NaN    Rain
# 2017-01-06          NaN        NaN   Sunny
# 2017-01-07          NaN        NaN     NaN
# 2017-01-08         34.0        8.0  Cloudy
# 2017-01-09         40.0       12.0   Sunny
# 2017-01-10          NaN        NaN     NaN
# 2017-01-11          NaN        NaN     NaN

# %% [markdown]
# # Dealing with special values

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book4.csv")
df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017       -99999          7  Sunny
# 2  01-03-2017           28     -99999   Snow
# 3  01-04-2017       -99999          7      0
# 4  01-05-2017           32     -99999   Rain
# 5  01-06-2017           31          2  Sunny
# 6  01-06-2017           34          5      0

# %%
#can pass replacing values as list
new_df = df.replace({'temperature':-99999,
                    'windspeed':-99999,'event':'0'
                    },np.NaN)
new_df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017          NaN        7.0  Sunny
# 2  01-03-2017         28.0        NaN   Snow
# 3  01-04-2017          NaN        7.0    NaN
# 4  01-05-2017         32.0        NaN   Rain
# 5  01-06-2017         31.0        2.0  Sunny
# 6  01-06-2017         34.0        5.0    NaN

# %%
new_df = df.replace({-99999:np.NaN,
                    '0':'Sunny'})
new_df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017          NaN        7.0  Sunny
# 2  01-03-2017         28.0        NaN   Snow
# 3  01-04-2017          NaN        7.0  Sunny
# 4  01-05-2017         32.0        NaN   Rain
# 5  01-06-2017         31.0        2.0  Sunny
# 6  01-06-2017         34.0        5.0  Sunny

# %%
#Regex Tut
#To replace full list replace by another list
new_df = df.replace({
    'temperature': '[A-Za-z]',
    'windspeed':'[A-Za-z]',
},'',regex=True)
new_df = df.replace({
                    '0':'Sunny'})
new_df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017       -99999          7  Sunny
# 2  01-03-2017           28     -99999   Snow
# 3  01-04-2017       -99999          7  Sunny
# 4  01-05-2017           32     -99999   Rain
# 5  01-06-2017           31          2  Sunny
# 6  01-06-2017           34          5  Sunny

# %% [markdown]
# # Split,Apply,Combine

# %%
#  import pandas as pd
#  df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book5.csv")
#  df
# Out:
#            day      city  temp  winds   event
# 0   01-01-2017  new york    32      6    Rain
# 1   01-02-2017  new york    36      7   Sunny
# 2   01-03-2017  new york    28     12    Snow
# 3   01-04-2017  new york    33      7   Sunny
# 4   01-01-2017    mumbai    90      5   Sunny
# 5   01-02-2017    mumbai    85     12    Fog
# 6   01-03-2017    mumbai    87     15    Fog
# 7   01-04-2017    mumbai    92      5    Rain
# 8   01-01-2017     paris    45     20   Sunny
# 9   01-02-2017     paris    50     13  Cloudy
# 10  01-03-2017     paris    54      8  Cloudy
# 11  01-04-2017     paris    42     10  Cloudy

# %%
# g = df.groupby('city')
# g

# %%
# for city,city_df in g:
#     print(city)
#     print(city_df)
# Out:
# mumbai
#           day    city  temp  winds  event
# 4  01-01-2017  mumbai    90      5  Sunny
# 5  01-02-2017  mumbai    85     12   Fog
# 6  01-03-2017  mumbai    87     15   Fog
# 7  01-04-2017  mumbai    92      5   Rain
# new york
#           day      city  temp  winds  event
# 0  01-01-2017  new york    32      6   Rain
# 1  01-02-2017  new york    36      7  Sunny
# 2  01-03-2017  new york    28     12   Snow
# 3  01-04-2017  new york    33      7  Sunny
# paris
#            day   city  temp  winds   event
# 8   01-01-2017  paris    45     20   Sunny
# 9   01-02-2017  paris    50     13  Cloudy
# 10  01-03-2017  paris    54      8  Cloudy
# 11  01-04-2017  paris    42     10  Cloudy

# %%
# g.get_group('mumbai')
# Out:
#           day    city  temp  winds  event
# 4  01-01-2017  mumbai    90      5  Sunny
# 5  01-02-2017  mumbai    85     12   Fog
# 6  01-03-2017  mumbai    87     15   Fog
# 7  01-04-2017  mumbai    92      5   Rain

# %%
# g.max()
# Out:
#                  day  temp  winds  event
# city
# mumbai    01-04-2017    92     15  Sunny
# new york  01-04-2017    36     12  Sunny
# paris     01-04-2017    54     20  Sunny

# %%
# g.mean()
# Out:
#            temp  winds
# city
# mumbai    88.50   9.25
# new york  32.25   8.00
# paris     47.75  12.75

# %%
# g.describe()
# Out:
#           temp                                                  winds         \
#          count   mean       std   min    25%   50%    75%   max count   mean
# city
# mumbai     4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0   4.0   9.25
# new york   4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0   4.0   8.00
# paris      4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0   4.0  12.75
#
#
#                std  min   25%   50%    75%   max
# city
# mumbai    5.057997  5.0  5.00   8.5  12.75  15.0
# new york  2.708013  6.0  6.75   7.0   8.25  12.0
# paris     5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
# g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# # Concating DataFrames

# %%
 import pandas as pd
india_weather = pd.DataFrame({
"city":["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity":[80,60,78]}
)
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
 import pandas as pd
us_weather = pd.DataFrame({
"city":["new york","chicago","orlandoo"],
    "temperature": [22,35,10],
    "humidity":[60,90,48]}
)
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           22        60
# 1   chicago           35        90
# 2  orlandoo           10        48

# %%
df =  pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           22        60
# 4   chicago           35        90
# 5  orlandoo           10        48

# %%
#if you want third pass axis = 1 amd index =[1,0]
df =  pd.concat([india_weather,us_weather],
                #ignore_index=True,
                keys=["india","us"])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           22        60
#       1   chicago           35        90
#       2  orlandoo           10        48

# %% [markdown]
# # Merging Dataframes

# %%
import pandas as pd
df1 = pd.DataFrame({
"city":["new york","chicago","baltimore","orlando"],
    "temperature": [22,35,77,10] }
)
df1
# Out:
#         city  temperature
# 0   new york           22
# 1    chicago           35
# 2  baltimore           77
# 3    orlando           10

# %%
import pandas as pd
df2 = pd.DataFrame({
"city":["new york","chicago","san frasico"],
   
    "humidity":[60,90,48]}
)
df2
# Out:
#           city  humidity
# 0     new york        60
# 1      chicago        90
# 2  san frasico        48

# %%
#it performs intersection,so for union
#to know the details data frame
#if same column use suffixes=("","")...to name thwm
df3 =pd.merge(df1,df2,on="city",how="outer",indicator="True")
df3
# Out:
#           city  temperature  humidity        True
# 0     new york         22.0      60.0        both
# 1      chicago         35.0      90.0        both
# 2    baltimore         77.0       NaN   left_only
# 3      orlando         10.0       NaN   left_only
# 4  san frasico          NaN      48.0  right_only

# %% [markdown]
# # Pivot Table

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book6.csv")
df
# Out:
#          date      city  temp  humidity
# 0  05-01-2017  new york    65        56
# 1  05-02-2017  new york    66        58
# 2  05-03-2017  new york    68        60
# 3  05-01-2017    mumbai    75        80
# 4  05-02-2017    mumbai    78        83
# 5  05-03-2017    mumbai    82        85
# 6  05-01-2017   beijing    80        26
# 7  05-02-2017   beijing    77        30
# 8  05-03-2017   beijing    79        35

# %%
#index...x...columns...y...values...only output data
df.pivot(index='date',columns='city',values='humidity')
# Out:
# city        beijing  mumbai  new york
# date
# 05-01-2017       26      80        56
# 05-02-2017       30      83        58
# 05-03-2017       35      85        60

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book7.csv")
df
# Out:
#          date      city  temp  humidity
# 0  05-01-2017  new york    65        56
# 1  05-01-2017  new york    61        54
# 2  05-02-2017  new york    70        60
# 3  05-02-2017  new york    72        62
# 4  05-01-2017    mumbai    75        80
# 5  05-01-2017    mumbai    78        83
# 6  05-02-2017    mumbai    82        85
# 7  05-02-2017    mumbai    80        26

# %%
#if similar values for a key pivot_table takes average...aggfunc
#margins give total/aggregate
df.pivot_table(index='city',columns='date',aggfunc="sum",margins=True)
# Out:
#            humidity                       temp
# date     05-01-2017 05-02-2017  All 05-01-2017 05-02-2017  All
# city
# mumbai          163        111  274        153        162  315
# new york        110        122  232        126        142  268
# All             273        233  506        279        304  583

# %%
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book8.csv")
df
# Out:
#          date      city  temp  humidity
# 0  05-01-2017  new york    65        56
# 1  05-02-2017  new york    61        54
# 2  05-03-2017  new york    70        60
# 3  12-01-2017  new york    30        50
# 4  12-02-2017  new york    26        52
# 5  12-03-2017  new york    25        51

# %%
#string to date conversion
df['date']=pd.to_datetime(df['date'])
df
# Out:
#         date      city  temp  humidity
# 0 2017-05-01  new york    65        56
# 1 2017-05-02  new york    61        54
# 2 2017-05-03  new york    70        60
# 3 2017-12-01  new york    30        50
# 4 2017-12-02  new york    26        52
# 5 2017-12-03  new york    25        51

# %%
#Grouper function
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#              humidity       temp
# city         new york   new york
# date
# 2017-05-31  56.666667  65.333333
# 2017-12-31  51.000000  27.000000

# %% [markdown]
# # Reshaping Dataframe using Melt

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book9.csv")
df
# Out:
#    day  chicago  chennai  berlin
# 0  Mon       32       75      41
# 1  Tue       30       77      43
# 2  Wed       28       75      45
# 3  Thu       22       82      38
# 4  Fri       30       83      30
# 5  Sat       20       81      45
# 6  Sun       25       77      47

# %%
#id vars ... not melted
df1=pd.melt(df,id_vars=["day"],var_name="city",value_name="temp")
df1#[df1["variable"]=="chicago"]...for specific
# Out:
#     day     city  temp
# 0   Mon  chicago    32
# 1   Tue  chicago    30
# 2   Wed  chicago    28
# 3   Thu  chicago    22
# 4   Fri  chicago    30
# 5   Sat  chicago    20
# 6   Sun  chicago    25
# 7   Mon  chennai    75
# 8   Tue  chennai    77
# 9   Wed  chennai    75
# 10  Thu  chennai    82
# 11  Fri  chennai    83
# 12  Sat  chennai    81
# 13  Sun  chennai    77
# 14  Mon   berlin    41
# 15  Tue   berlin    43
# 16  Wed   berlin    45
# 17  Thu   berlin    38
# 18  Fri   berlin    30
# 19  Sat   berlin    45
# 20  Sun   berlin    47

# %% [markdown]
# # Stacking & Unstacking

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Aditya Singh\Documents\Book10.xlsx",header=[0,1],index_col=[0])


df
# Out:
#               Price                  Price to earning ratio(P/E)         \
# Company    Facebook Google Microsoft                    Facebook Google
# 2017-06-05      155    955        66                       37.10   32.0
# 2017-06-06      150    987        69                       36.98   31.3
# 2017-06-07      153    963        62                       36.78   31.7
# 2017-06-08      155   1000        61                       36.11   31.2
# 2017-06-09      156   1012        66                       37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# 2017-06-08     30.11
# 2017-06-09     31.00

# %%
df_stacked=df.stack(dropna=True)
df_stacked
# Out:
#                       Price  Price to earning ratio(P/E)
#            Company
# 2017-06-05 Facebook     155                        37.10
#            Google       955                        32.00
#            Microsoft     66                        30.31
# 2017-06-06 Facebook     150                        36.98
#            Google       987                        31.30
#            Microsoft     69                        30.56
# 2017-06-07 Facebook     153                        36.78
#            Google       963                        31.70
#            Microsoft     62                        30.46
# 2017-06-08 Facebook     155                        36.11
#            Google      1000                        31.20
#            Microsoft     61                        30.11
# 2017-06-09 Facebook     156                        37.07
#            Google      1012                        30.00
#            Microsoft     66                        31.00

# %%
df_stacked.unstack()
# Out:
#               Price                  Price to earning ratio(P/E)         \
# Company    Facebook Google Microsoft                    Facebook Google
# 2017-06-05      155    955        66                       37.10   32.0
# 2017-06-06      150    987        69                       36.98   31.3
# 2017-06-07      153    963        62                       36.78   31.7
# 2017-06-08      155   1000        61                       36.11   31.2
# 2017-06-09      156   1012        66                       37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# 2017-06-08     30.11
# 2017-06-09     31.00

# %% [markdown]
# # Crosstab

# %%
# %%HTML
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border: 1px solid gray;
#     }
# </style>
# Out:
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border: 1px solid gray;
#     }
# </style>

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Aditya Singh\Documents\Book11.csv")
df
# Out:
#       Name Nationality     Sex  Age Handeness
# 0    Kathy         USA  Female   23     Right
# 1    Linda         USA  Female   18     Right
# 2    Peter         USA    Male   19     Right
# 3     John         USA    Male   22      Left
# 4   Fatima  Bangladesh  Female   31      Left
# 5    Kadir  Bangladesh    Male   25      Left
# 6   Dhaval       India    Male   35      Left
# 7   Sudhir       India    Male   31      Left
# 8   Parvir       India    Male   37     Right
# 9      Yan       China  Female   52     Right
# 10    Juan       China  Female   58      Left
# 11   Liang       China    Male   43      Left

# %% [markdown]
# pd.crosstab(df.Nationality,df.Handeness)#values=df.Age,aggfunc=np.average

# %%
#shift + tab....normalize='index'...for percentage
pd.crosstab(df.Sex,[df.Handeness,df.Nationality],margins=True)
# Out:
# Handeness         Left                 Right           All
# Nationality Bangladesh China India USA China India USA
# Sex
# Female               1     1     0   0     1     0   2   5
# Male                 1     1     2   1     0     1   1   7
# All                  2     2     2   1     1     1   3  12

# %% [markdown]
# # Time series analysis

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
#the prev Date column was string so we use parse to convert it
#then we replaced deafault index by date time
df = pd.read_csv(r"C:\Users\Aditya Singh\Downloads\HistoricalData_1641821692395.csv",parse_dates=["Date"],index_col="Date")
df.head(5)
# Out:
#               Close     Volume     Open     High      Low
# Date
# 2022-01-07  $172.17   86709150  $172.89  $174.14  $171.03
# 2022-01-06     $172   96903960   $172.7   $175.3  $171.64
# 2022-01-05  $174.92   94537600  $179.61  $180.17  $174.64
# 2022-01-04   $179.7   99310440  $182.63  $182.94  $179.12
# 2022-01-03  $182.01  104701200  $177.83  $182.88  $177.71

# %%
charti = df['Close']
for i in range(len(charti)):
    charti[i]=charti[i].replace('$','')
#print(charti)
df['Close']=charti
df.head(5)
# Out:
#              Close     Volume     Open     High      Low
# Date
# 2022-01-07  172.17   86709150  $172.89  $174.14  $171.03
# 2022-01-06     172   96903960   $172.7   $175.3  $171.64
# 2022-01-05  174.92   94537600  $179.61  $180.17  $174.64
# 2022-01-04   179.7   99310440  $182.63  $182.94  $179.12
# 2022-01-03  182.01  104701200  $177.83  $182.88  $177.71

# %%
df['Close']=pd.to_numeric(df['Close'])

# %%
type(df['Volume'])
# Out:
# pandas.core.series.Series

# %%
df.index
# Out:
# DatetimeIndex(['2022-01-07', '2022-01-06', '2022-01-05', '2022-01-04',
#                '2022-01-03', '2021-12-31', '2021-12-30', '2021-12-29',
#                '2021-12-28', '2021-12-27',
#                ...
#                '2021-01-25', '2021-01-22', '2021-01-21', '2021-01-20',
#                '2021-01-19', '2021-01-15', '2021-01-14', '2021-01-13',
#                '2021-01-12', '2021-01-11'],
#               dtype='datetime64[ns]', name='Date', length=252, freq=None)

# %%
df["2021-07":"2021-03"].Volume.mean()
# Out:
# 91386232.9906542

# %%
# %matplotlib inline
df.Close.resample('Q').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.plot()
#without resampling the graph is way too granualar
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#For Missing Dates Column
import pandas as pd
df = pd.read_csv(r"C:\Users\Aditya Singh\Downloads\HistoricalData_1641821692395_2.csv")
df.head()
# Out:
#      Close     Volume     Open     High      Low
# 0  $172.17   86709150  $172.89  $174.14  $171.03
# 1     $172   96903960   $172.7   $175.3  $171.64
# 2  $174.92   94537600  $179.61  $180.17  $174.64
# 3   $179.7   99310440  $182.63  $182.94  $179.12
# 4  $182.01  104701200  $177.83  $182.88  $177.71

# %%
charti = df['Close']
for i in range(len(charti)):
    charti[i]=charti[i].replace('$','')
#print(charti)
df['Close']=charti
df.head(5)
df['Close']=pd.to_numeric(df['Close'])

# %%
#if dont know end... 
#rng = pd.date_range(start="5/1/2021",periods=252,freq='B')
#doesnt handle holidays specific to calender
rng = pd.date_range(start="5/1/2021",end="4/19/2022",freq='B')
rng
# Out:
# DatetimeIndex(['2021-05-03', '2021-05-04', '2021-05-05', '2021-05-06',
#                '2021-05-07', '2021-05-10', '2021-05-11', '2021-05-12',
#                '2021-05-13', '2021-05-14',
#                ...
#                '2022-04-06', '2022-04-07', '2022-04-08', '2022-04-11',
#                '2022-04-12', '2022-04-13', '2022-04-14', '2022-04-15',
#                '2022-04-18', '2022-04-19'],
#               dtype='datetime64[ns]', length=252, freq='B')

# %%
df.set_index(rng,inplace=True)
df
# Out:
#              Close     Volume     Open       High      Low
# 2021-05-03  172.17   86709150  $172.89    $174.14  $171.03
# 2021-05-04  172.00   96903960   $172.7     $175.3  $171.64
# 2021-05-05  174.92   94537600  $179.61    $180.17  $174.64
# 2021-05-06  179.70   99310440  $182.63    $182.94  $179.12
# 2021-05-07  182.01  104701200  $177.83    $182.88  $177.71
# ...            ...        ...      ...        ...      ...
# 2022-04-13  127.14  111598500  $128.78  $130.2242     $127
# 2022-04-14  128.91   90221760   $130.8       $131  $128.76
# 2022-04-15  130.89   88636830  $128.76    $131.45  $128.49
# 2022-04-18  128.80   91951150   $128.5    $129.69  $126.86
# 2022-04-19  128.98  100620900  $129.19    $130.17   $128.5
#
# [252 rows x 5 columns]

# %%
# %matplotlib inline
df.Close.plot()
# Out:
# <AxesSubplot:>

# %%
df["2021-05-03":"2021-08-03"].Close.mean()
# Out:
# 159.90119402985073

# %%
#helps regenerte data frame acc to new freq
#pad helps carry forward the prices/data similar to fill na
df.asfreq('D',method='pad')
# Out:
#              Close     Volume     Open     High      Low
# 2021-05-03  172.17   86709150  $172.89  $174.14  $171.03
# 2021-05-04  172.00   96903960   $172.7   $175.3  $171.64
# 2021-05-05  174.92   94537600  $179.61  $180.17  $174.64
# 2021-05-06  179.70   99310440  $182.63  $182.94  $179.12
# 2021-05-07  182.01  104701200  $177.83  $182.88  $177.71
# ...            ...        ...      ...      ...      ...
# 2022-04-15  130.89   88636830  $128.76  $131.45  $128.49
# 2022-04-16  130.89   88636830  $128.76  $131.45  $128.49
# 2022-04-17  130.89   88636830  $128.76  $131.45  $128.49
# 2022-04-18  128.80   91951150   $128.5  $129.69  $126.86
# 2022-04-19  128.98  100620900  $129.19  $130.17   $128.5
#
# [352 rows x 5 columns]

# %%
import numpy as np
#pd.to_datetime(dates)....pd.to_datetime('5$12$2020',format='%d$%m$%Y')

ts = pd.Series(np.random.randint(1,10,len(rng)),index =rng)
ts.head(10)
#len(rng)
# Out:
# 2021-05-03    9
# 2021-05-04    3
# 2021-05-05    2
# 2021-05-06    6
# 2021-05-07    8
# 2021-05-10    8
# 2021-05-11    5
# 2021-05-12    5
# 2021-05-13    2
# 2021-05-14    1
# Freq: B, dtype: int32

# %%
#Time Period
# provide freq argument = 'M'...for monthly 
import pandas as pd
y = pd.Period('2016')
y
# Out:
# Period('2016', 'A-DEC')

# %%
dir(y)#y.start_time
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_delta',
#  '_add_offset',
#  '_dtype',
#  '_from_ordinal',
#  '_get_to_timestamp_base',
#  '_maybe_convert_freq',
#  'asfreq',
#  'day',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'end_time',
#  'freq',
#  'freqstr',
#  'hour',
#  'is_leap_year',
#  'minute',
#  'month',
#  'now',
#  'ordinal',
#  'quarter',
#  'qyear',
#  'second',
#  'start_time',
#  'strftime',
#  'to_timestamp',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
d = pd.Period('2016-02-28')
d
# Out:
# Period('2016-02-28', 'D')

# %%
d+1
# Out:
# Period('2016-02-29', 'D')

# %%
#quarterly tp
q = pd.Period('2017Q1',freq ='Q-JAN')
q
# Out:
# Period('2017Q1', 'Q-JAN')

# %%
q.start_time
# Out:
# Timestamp('2016-02-01 00:00:00')

# %%
q.asfreq('M',how="start")
# Out:
# Period('2016-02', 'M')

# %%
idx = pd.period_range('2011','2017',freq='Q-JAN')
idx
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3',
#              '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1',
#              '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3',
#              '2017Q4'],
#             dtype='period[Q-JAN]', freq='Q-JAN')

# %%
idx[0].start_time
# Out:
# Timestamp('2010-11-01 00:00:00')

# %%
idx[0].end_time
# Out:
# Timestamp('2011-01-31 23:59:59.999999999')

# %%
import numpy as np
ps =pd.Series(np.random.randn(len(idx)),idx)
ps
# Out:
# 2011Q4    0.392565
# 2012Q1   -1.626050
# 2012Q2    0.323686
# 2012Q3    1.464884
# 2012Q4    1.087593
# 2013Q1    0.645974
# 2013Q2   -1.174211
# 2013Q3   -0.140474
# 2013Q4   -1.134200
# 2014Q1    0.719126
# 2014Q2   -1.324262
# 2014Q3    0.341072
# 2014Q4    0.344969
# 2015Q1    0.314687
# 2015Q2    0.631923
# 2015Q3   -1.822326
# 2015Q4   -0.417305
# 2016Q1   -0.227311
# 2016Q2   -0.387055
# 2016Q3   -0.122629
# 2016Q4   -1.939778
# 2017Q1    0.790460
# 2017Q2    0.012833
# 2017Q3    0.179257
# 2017Q4   -1.626590
# Freq: Q-JAN, dtype: float64

# %%
ps.index
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3',
#              '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1',
#              '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3',
#              '2017Q4'],
#             dtype='period[Q-JAN]', freq='Q-JAN')
